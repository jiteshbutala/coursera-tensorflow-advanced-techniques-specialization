# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Get the data from UCI dataset
URL = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00242/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URL)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = np.array(norm(train))
norm_test_X = np.array(norm(test))

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 8)]                  0         []
#
#  dense_3 (Dense)             (None, 128)                  1152      ['input_2[0][0]']
#
#  dense_4 (Dense)             (None, 128)                  16512     ['dense_3[0][0]']
#
#  dense_5 (Dense)             (None, 64)                   8256      ['dense_4[0][0]']
#
#  y1_output (Dense)           (None, 1)                    129       ['dense_4[0][0]']
#
#  y2_output (Dense)           (None, 1)                    65        ['dense_5[0][0]']
#
# ==================================================================================================
# Total params: 26114 (102.01 KB)
# Trainable params: 26114 (102.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(learning_rate=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Epoch 1/500
# 62/62 [==============================] - 2s 12ms/step - loss: 252.4111 - y1_output_loss: 123.8111 - y2_output_loss: 128.6000 - y1_output_root_mean_squared_error: 11.1270 - y2_output_root_mean_squared_error: 11.3402 - val_loss: 115.3801 - val_y1_output_loss: 27.0934 - val_y2_output_loss: 88.2868 - val_y1_output_root_mean_squared_error: 5.2051 - val_y2_output_root_mean_squared_error: 9.3961
# Epoch 2/500
# 62/62 [==============================] - 0s 4ms/step - loss: 31.6899 - y1_output_loss: 12.1775 - y2_output_loss: 19.5124 - y1_output_root_mean_squared_error: 3.4896 - y2_output_root_mean_squared_error: 4.4173 - val_loss: 114.1125 - val_y1_output_loss: 27.0701 - val_y2_output_loss: 87.0424 - val_y1_output_root_mean_squared_error: 5.2029 - val_y2_output_root_mean_squared_error: 9.3297
# Epoch 3/500
# 62/62 [==============================] - 0s 4ms/step - loss: 27.5474 - y1_output_loss: 10.8443 - y2_output_loss: 16.7031 - y1_output_root_mean_squared_error: 3.2931 - y2_output_root_mean_squared_error: 4.0869 - val_loss: 31.8492 - val_y1_output_loss: 12.0952 - val_y2_output_loss: 19.7540 - val_y1_output_root_mean_squared_error: 3.4778 - val_y2_output_root_mean_squared_error: 4.4445
# Epoch 4/500
# 62/62 [==============================] - 0s 5ms/step - loss: 23.6339 - y1_output_loss: 9.1853 - y2_output_loss: 14.4486 - y1_output_root_mean_squared_error: 3.0307 - y2_output_root_mean_squared_error: 3.8011 - val_loss: 25.1403 - val_y1_output_loss: 9.9663 - val_y2_output_loss: 15.1739 - val_y1_output_root_mean_squared_error: 3.1570 - val_y2_output_root_mean_squared_error: 3.8954
# Epoch 5/500
# 62/62 [==============================] - 0s 5ms/step - loss: 23.4347 - y1_output_loss: 9.0516 - y2_output_loss: 14.3831 - y1_output_root_mean_squared_error: 3.0086 - y2_output_root_mean_squared_error: 3.7925 - val_loss: 43.7338 - val_y1_output_loss: 14.3215 - val_y2_output_loss: 29.4124 - val_y1_output_root_mean_squared_error: 3.7844 - val_y2_output_root_mean_squared_error: 5.4233
# Epoch 6/500
# 62/62 [==============================] - 0s 6ms/step - loss: 24.2427 - y1_output_loss: 9.1345 - y2_output_loss: 15.1082 - y1_output_root_mean_squared_error: 3.0223 - y2_output_root_mean_squared_error: 3.8869 - val_loss: 25.7658 - val_y1_output_loss: 9.3503 - val_y2_output_loss: 16.4155 - val_y1_output_root_mean_squared_error: 3.0578 - val_y2_output_root_mean_squared_error: 4.0516
# Epoch 7/500
# 62/62 [==============================] - 0s 5ms/step - loss: 21.5242 - y1_output_loss: 8.4265 - y2_output_loss: 13.0977 - y1_output_root_mean_squared_error: 2.9028 - y2_output_root_mean_squared_error: 3.6191 - val_loss: 19.7649 - val_y1_output_loss: 8.4483 - val_y2_output_loss: 11.3166 - val_y1_output_root_mean_squared_error: 2.9066 - val_y2_output_root_mean_squared_error: 3.3640
# Epoch 8/500
# 62/62 [==============================] - 0s 5ms/step - loss: 24.9326 - y1_output_loss: 9.0358 - y2_output_loss: 15.8968 - y1_output_root_mean_squared_error: 3.0060 - y2_output_root_mean_squared_error: 3.9871 - val_loss: 21.5843 - val_y1_output_loss: 8.6435 - val_y2_output_loss: 12.9408 - val_y1_output_root_mean_squared_error: 2.9400 - val_y2_output_root_mean_squared_error: 3.5973
# Epoch 9/500
# 62/62 [==============================] - 0s 4ms/step - loss: 19.4166 - y1_output_loss: 7.9765 - y2_output_loss: 11.4401 - y1_output_root_mean_squared_error: 2.8243 - y2_output_root_mean_squared_error: 3.3823 - val_loss: 38.9063 - val_y1_output_loss: 13.2975 - val_y2_output_loss: 25.6087 - val_y1_output_root_mean_squared_error: 3.6466 - val_y2_output_root_mean_squared_error: 5.0605
# Epoch 10/500
# 62/62 [==============================] - 0s 5ms/step - loss: 20.5734 - y1_output_loss: 8.2178 - y2_output_loss: 12.3556 - y1_output_root_mean_squared_error: 2.8667 - y2_output_root_mean_squared_error: 3.5150 - val_loss: 20.9964 - val_y1_output_loss: 8.2198 - val_y2_output_loss: 12.7766 - val_y1_output_root_mean_squared_error: 2.8670 - val_y2_output_root_mean_squared_error: 3.5744
# Epoch 11/500
# 62/62 [==============================] - 0s 5ms/step - loss: 22.8843 - y1_output_loss: 8.2443 - y2_output_loss: 14.6401 - y1_output_root_mean_squared_error: 2.8713 - y2_output_root_mean_squared_error: 3.8262 - val_loss: 23.8700 - val_y1_output_loss: 8.4430 - val_y2_output_loss: 15.4270 - val_y1_output_root_mean_squared_error: 2.9057 - val_y2_output_root_mean_squared_error: 3.9277
# Epoch 12/500
# 62/62 [==============================] - 0s 5ms/step - loss: 20.7196 - y1_output_loss: 8.0337 - y2_output_loss: 12.6859 - y1_output_root_mean_squared_error: 2.8344 - y2_output_root_mean_squared_error: 3.5617 - val_loss: 95.1097 - val_y1_output_loss: 17.4545 - val_y2_output_loss: 77.6552 - val_y1_output_root_mean_squared_error: 4.1779 - val_y2_output_root_mean_squared_error: 8.8122
# Epoch 13/500
# 62/62 [==============================] - 0s 5ms/step - loss: 19.5575 - y1_output_loss: 7.7437 - y2_output_loss: 11.8139 - y1_output_root_mean_squared_error: 2.7827 - y2_output_root_mean_squared_error: 3.4371 - val_loss: 26.7950 - val_y1_output_loss: 8.5467 - val_y2_output_loss: 18.2483 - val_y1_output_root_mean_squared_error: 2.9235 - val_y2_output_root_mean_squared_error: 4.2718
# Epoch 14/500
# 62/62 [==============================] - 0s 5ms/step - loss: 19.8285 - y1_output_loss: 7.4213 - y2_output_loss: 12.4072 - y1_output_root_mean_squared_error: 2.7242 - y2_output_root_mean_squared_error: 3.5224 - val_loss: 64.2400 - val_y1_output_loss: 18.0778 - val_y2_output_loss: 46.1622 - val_y1_output_root_mean_squared_error: 4.2518 - val_y2_output_root_mean_squared_error: 6.7943
# Epoch 15/500
# 62/62 [==============================] - 0s 5ms/step - loss: 20.2672 - y1_output_loss: 8.0777 - y2_output_loss: 12.1895 - y1_output_root_mean_squared_error: 2.8421 - y2_output_root_mean_squared_error: 3.4913 - val_loss: 19.1814 - val_y1_output_loss: 7.2538 - val_y2_output_loss: 11.9276 - val_y1_output_root_mean_squared_error: 2.6933 - val_y2_output_root_mean_squared_error: 3.4536
# Epoch 16/500
# 62/62 [==============================] - 0s 5ms/step - loss: 17.8525 - y1_output_loss: 7.0930 - y2_output_loss: 10.7595 - y1_output_root_mean_squared_error: 2.6633 - y2_output_root_mean_squared_error: 3.2802 - val_loss: 15.9853 - val_y1_output_loss: 6.7046 - val_y2_output_loss: 9.2807 - val_y1_output_root_mean_squared_error: 2.5893 - val_y2_output_root_mean_squared_error: 3.0464
# Epoch 17/500
# 62/62 [==============================] - 0s 5ms/step - loss: 19.4217 - y1_output_loss: 6.9626 - y2_output_loss: 12.4590 - y1_output_root_mean_squared_error: 2.6387 - y2_output_root_mean_squared_error: 3.5297 - val_loss: 35.1145 - val_y1_output_loss: 10.9039 - val_y2_output_loss: 24.2106 - val_y1_output_root_mean_squared_error: 3.3021 - val_y2_output_root_mean_squared_error: 4.9204
# Epoch 18/500
# 62/62 [==============================] - 0s 5ms/step - loss: 16.6438 - y1_output_loss: 6.6881 - y2_output_loss: 9.9557 - y1_output_root_mean_squared_error: 2.5861 - y2_output_root_mean_squared_error: 3.1553 - val_loss: 20.3152 - val_y1_output_loss: 7.7520 - val_y2_output_loss: 12.5632 - val_y1_output_root_mean_squared_error: 2.7842 - val_y2_output_root_mean_squared_error: 3.5445
# Epoch 19/500
# 62/62 [==============================] - 0s 5ms/step - loss: 16.6001 - y1_output_loss: 6.5714 - y2_output_loss: 10.0288 - y1_output_root_mean_squared_error: 2.5635 - y2_output_root_mean_squared_error: 3.1668 - val_loss: 17.3398 - val_y1_output_loss: 6.5386 - val_y2_output_loss: 10.8012 - val_y1_output_root_mean_squared_error: 2.5571 - val_y2_output_root_mean_squared_error: 3.2865
# Epoch 20/500
# 62/62 [==============================] - 0s 5ms/step - loss: 16.8213 - y1_output_loss: 6.2927 - y2_output_loss: 10.5286 - y1_output_root_mean_squared_error: 2.5085 - y2_output_root_mean_squared_error: 3.2448 - val_loss: 15.5328 - val_y1_output_loss: 5.4436 - val_y2_output_loss: 10.0892 - val_y1_output_root_mean_squared_error: 2.3332 - val_y2_output_root_mean_squared_error: 3.1763
# Epoch 21/500
# 62/62 [==============================] - 0s 6ms/step - loss: 16.2719 - y1_output_loss: 6.0852 - y2_output_loss: 10.1867 - y1_output_root_mean_squared_error: 2.4668 - y2_output_root_mean_squared_error: 3.1917 - val_loss: 13.5055 - val_y1_output_loss: 5.8955 - val_y2_output_loss: 7.6100 - val_y1_output_root_mean_squared_error: 2.4281 - val_y2_output_root_mean_squared_error: 2.7586
# Epoch 22/500
# 62/62 [==============================] - 0s 6ms/step - loss: 14.1657 - y1_output_loss: 5.5826 - y2_output_loss: 8.5831 - y1_output_root_mean_squared_error: 2.3628 - y2_output_root_mean_squared_error: 2.9297 - val_loss: 14.1823 - val_y1_output_loss: 5.5335 - val_y2_output_loss: 8.6488 - val_y1_output_root_mean_squared_error: 2.3523 - val_y2_output_root_mean_squared_error: 2.9409
# Epoch 23/500
# 62/62 [==============================] - 0s 5ms/step - loss: 20.2584 - y1_output_loss: 6.8477 - y2_output_loss: 13.4107 - y1_output_root_mean_squared_error: 2.6168 - y2_output_root_mean_squared_error: 3.6621 - val_loss: 29.8653 - val_y1_output_loss: 10.4079 - val_y2_output_loss: 19.4574 - val_y1_output_root_mean_squared_error: 3.2261 - val_y2_output_root_mean_squared_error: 4.4111
# Epoch 24/500
# 62/62 [==============================] - 0s 5ms/step - loss: 12.9647 - y1_output_loss: 5.4920 - y2_output_loss: 7.4726 - y1_output_root_mean_squared_error: 2.3435 - y2_output_root_mean_squared_error: 2.7336 - val_loss: 11.8817 - val_y1_output_loss: 4.8102 - val_y2_output_loss: 7.0714 - val_y1_output_root_mean_squared_error: 2.1932 - val_y2_output_root_mean_squared_error: 2.6592
# Epoch 25/500
# 62/62 [==============================] - 0s 4ms/step - loss: 14.3694 - y1_output_loss: 5.1890 - y2_output_loss: 9.1805 - y1_output_root_mean_squared_error: 2.2779 - y2_output_root_mean_squared_error: 3.0299 - val_loss: 14.3140 - val_y1_output_loss: 5.5085 - val_y2_output_loss: 8.8054 - val_y1_output_root_mean_squared_error: 2.3470 - val_y2_output_root_mean_squared_error: 2.9674
# Epoch 26/500
# 62/62 [==============================] - 0s 6ms/step - loss: 12.1489 - y1_output_loss: 4.6522 - y2_output_loss: 7.4967 - y1_output_root_mean_squared_error: 2.1569 - y2_output_root_mean_squared_error: 2.7380 - val_loss: 18.1719 - val_y1_output_loss: 5.8629 - val_y2_output_loss: 12.3090 - val_y1_output_root_mean_squared_error: 2.4213 - val_y2_output_root_mean_squared_error: 3.5084
# Epoch 27/500
# 62/62 [==============================] - 0s 6ms/step - loss: 12.5397 - y1_output_loss: 4.7106 - y2_output_loss: 7.8291 - y1_output_root_mean_squared_error: 2.1704 - y2_output_root_mean_squared_error: 2.7981 - val_loss: 45.1716 - val_y1_output_loss: 14.5405 - val_y2_output_loss: 30.6311 - val_y1_output_root_mean_squared_error: 3.8132 - val_y2_output_root_mean_squared_error: 5.5345
# Epoch 28/500
# 62/62 [==============================] - 0s 5ms/step - loss: 12.2771 - y1_output_loss: 4.7838 - y2_output_loss: 7.4932 - y1_output_root_mean_squared_error: 2.1872 - y2_output_root_mean_squared_error: 2.7374 - val_loss: 28.6269 - val_y1_output_loss: 7.5216 - val_y2_output_loss: 21.1053 - val_y1_output_root_mean_squared_error: 2.7426 - val_y2_output_root_mean_squared_error: 4.5940
# Epoch 29/500
# 62/62 [==============================] - 0s 5ms/step - loss: 11.9770 - y1_output_loss: 4.4766 - y2_output_loss: 7.5004 - y1_output_root_mean_squared_error: 2.1158 - y2_output_root_mean_squared_error: 2.7387 - val_loss: 22.2078 - val_y1_output_loss: 4.9207 - val_y2_output_loss: 17.2872 - val_y1_output_root_mean_squared_error: 2.2183 - val_y2_output_root_mean_squared_error: 4.1578
# Epoch 30/500
# 62/62 [==============================] - 0s 5ms/step - loss: 12.5101 - y1_output_loss: 4.3302 - y2_output_loss: 8.1799 - y1_output_root_mean_squared_error: 2.0809 - y2_output_root_mean_squared_error: 2.8601 - val_loss: 11.7978 - val_y1_output_loss: 5.3225 - val_y2_output_loss: 6.4753 - val_y1_output_root_mean_squared_error: 2.3071 - val_y2_output_root_mean_squared_error: 2.5447
# Epoch 31/500
# 62/62 [==============================] - 0s 5ms/step - loss: 10.9359 - y1_output_loss: 4.0832 - y2_output_loss: 6.8527 - y1_output_root_mean_squared_error: 2.0207 - y2_output_root_mean_squared_error: 2.6178 - val_loss: 9.8558 - val_y1_output_loss: 3.8361 - val_y2_output_loss: 6.0197 - val_y1_output_root_mean_squared_error: 1.9586 - val_y2_output_root_mean_squared_error: 2.4535
# Epoch 32/500
# 62/62 [==============================] - 0s 7ms/step - loss: 10.8828 - y1_output_loss: 4.0703 - y2_output_loss: 6.8125 - y1_output_root_mean_squared_error: 2.0175 - y2_output_root_mean_squared_error: 2.6101 - val_loss: 18.8224 - val_y1_output_loss: 4.0369 - val_y2_output_loss: 14.7855 - val_y1_output_root_mean_squared_error: 2.0092 - val_y2_output_root_mean_squared_error: 3.8452
# Epoch 33/500
# 62/62 [==============================] - 0s 6ms/step - loss: 9.6977 - y1_output_loss: 3.5312 - y2_output_loss: 6.1665 - y1_output_root_mean_squared_error: 1.8792 - y2_output_root_mean_squared_error: 2.4832 - val_loss: 9.0223 - val_y1_output_loss: 3.6358 - val_y2_output_loss: 5.3865 - val_y1_output_root_mean_squared_error: 1.9068 - val_y2_output_root_mean_squared_error: 2.3209
# Epoch 34/500
# 62/62 [==============================] - 0s 4ms/step - loss: 9.8241 - y1_output_loss: 3.5935 - y2_output_loss: 6.2306 - y1_output_root_mean_squared_error: 1.8957 - y2_output_root_mean_squared_error: 2.4961 - val_loss: 9.9908 - val_y1_output_loss: 3.4366 - val_y2_output_loss: 6.5542 - val_y1_output_root_mean_squared_error: 1.8538 - val_y2_output_root_mean_squared_error: 2.5601
# Epoch 35/500
# 62/62 [==============================] - 0s 5ms/step - loss: 11.0808 - y1_output_loss: 3.7569 - y2_output_loss: 7.3239 - y1_output_root_mean_squared_error: 1.9383 - y2_output_root_mean_squared_error: 2.7063 - val_loss: 13.9474 - val_y1_output_loss: 4.1795 - val_y2_output_loss: 9.7680 - val_y1_output_root_mean_squared_error: 2.0444 - val_y2_output_root_mean_squared_error: 3.1254
# Epoch 36/500
# 62/62 [==============================] - 0s 4ms/step - loss: 9.6788 - y1_output_loss: 3.4593 - y2_output_loss: 6.2195 - y1_output_root_mean_squared_error: 1.8599 - y2_output_root_mean_squared_error: 2.4939 - val_loss: 15.0706 - val_y1_output_loss: 5.3654 - val_y2_output_loss: 9.7052 - val_y1_output_root_mean_squared_error: 2.3163 - val_y2_output_root_mean_squared_error: 3.1153
# Epoch 37/500
# 62/62 [==============================] - 0s 4ms/step - loss: 7.9886 - y1_output_loss: 3.1373 - y2_output_loss: 4.8513 - y1_output_root_mean_squared_error: 1.7712 - y2_output_root_mean_squared_error: 2.2026 - val_loss: 14.9404 - val_y1_output_loss: 4.1988 - val_y2_output_loss: 10.7417 - val_y1_output_root_mean_squared_error: 2.0491 - val_y2_output_root_mean_squared_error: 3.2775
# Epoch 38/500
# 62/62 [==============================] - 0s 5ms/step - loss: 8.0889 - y1_output_loss: 2.8186 - y2_output_loss: 5.2703 - y1_output_root_mean_squared_error: 1.6789 - y2_output_root_mean_squared_error: 2.2957 - val_loss: 79.8273 - val_y1_output_loss: 13.7810 - val_y2_output_loss: 66.0463 - val_y1_output_root_mean_squared_error: 3.7123 - val_y2_output_root_mean_squared_error: 8.1269
# Epoch 39/500
# 62/62 [==============================] - 0s 5ms/step - loss: 9.1687 - y1_output_loss: 3.1666 - y2_output_loss: 6.0021 - y1_output_root_mean_squared_error: 1.7795 - y2_output_root_mean_squared_error: 2.4499 - val_loss: 8.3854 - val_y1_output_loss: 2.8369 - val_y2_output_loss: 5.5485 - val_y1_output_root_mean_squared_error: 1.6843 - val_y2_output_root_mean_squared_error: 2.3555
# Epoch 40/500
# 62/62 [==============================] - 0s 6ms/step - loss: 6.5986 - y1_output_loss: 2.3525 - y2_output_loss: 4.2461 - y1_output_root_mean_squared_error: 1.5338 - y2_output_root_mean_squared_error: 2.0606 - val_loss: 6.7668 - val_y1_output_loss: 2.4189 - val_y2_output_loss: 4.3479 - val_y1_output_root_mean_squared_error: 1.5553 - val_y2_output_root_mean_squared_error: 2.0852
# Epoch 41/500
# 62/62 [==============================] - 0s 5ms/step - loss: 6.9743 - y1_output_loss: 2.4808 - y2_output_loss: 4.4935 - y1_output_root_mean_squared_error: 1.5750 - y2_output_root_mean_squared_error: 2.1198 - val_loss: 11.1553 - val_y1_output_loss: 3.0251 - val_y2_output_loss: 8.1302 - val_y1_output_root_mean_squared_error: 1.7393 - val_y2_output_root_mean_squared_error: 2.8513
# Epoch 42/500
# 62/62 [==============================] - 0s 5ms/step - loss: 8.2938 - y1_output_loss: 2.9091 - y2_output_loss: 5.3847 - y1_output_root_mean_squared_error: 1.7056 - y2_output_root_mean_squared_error: 2.3205 - val_loss: 14.5574 - val_y1_output_loss: 5.1247 - val_y2_output_loss: 9.4327 - val_y1_output_root_mean_squared_error: 2.2638 - val_y2_output_root_mean_squared_error: 3.0713
# Epoch 43/500
# 62/62 [==============================] - 0s 4ms/step - loss: 7.6608 - y1_output_loss: 2.4679 - y2_output_loss: 5.1929 - y1_output_root_mean_squared_error: 1.5710 - y2_output_root_mean_squared_error: 2.2788 - val_loss: 7.3991 - val_y1_output_loss: 2.9308 - val_y2_output_loss: 4.4684 - val_y1_output_root_mean_squared_error: 1.7120 - val_y2_output_root_mean_squared_error: 2.1138
# Epoch 44/500
# 62/62 [==============================] - 0s 5ms/step - loss: 8.3216 - y1_output_loss: 2.8681 - y2_output_loss: 5.4535 - y1_output_root_mean_squared_error: 1.6935 - y2_output_root_mean_squared_error: 2.3353 - val_loss: 11.0621 - val_y1_output_loss: 3.6747 - val_y2_output_loss: 7.3874 - val_y1_output_root_mean_squared_error: 1.9169 - val_y2_output_root_mean_squared_error: 2.7180
# Epoch 45/500
# 62/62 [==============================] - 0s 5ms/step - loss: 7.3160 - y1_output_loss: 2.4170 - y2_output_loss: 4.8990 - y1_output_root_mean_squared_error: 1.5547 - y2_output_root_mean_squared_error: 2.2134 - val_loss: 7.7615 - val_y1_output_loss: 2.6599 - val_y2_output_loss: 5.1016 - val_y1_output_root_mean_squared_error: 1.6309 - val_y2_output_root_mean_squared_error: 2.2587
# Epoch 46/500
# 62/62 [==============================] - 0s 5ms/step - loss: 7.7224 - y1_output_loss: 2.4812 - y2_output_loss: 5.2412 - y1_output_root_mean_squared_error: 1.5752 - y2_output_root_mean_squared_error: 2.2894 - val_loss: 6.3925 - val_y1_output_loss: 1.9692 - val_y2_output_loss: 4.4233 - val_y1_output_root_mean_squared_error: 1.4033 - val_y2_output_root_mean_squared_error: 2.1032
# Epoch 47/500
# 62/62 [==============================] - 0s 5ms/step - loss: 5.9281 - y1_output_loss: 2.0012 - y2_output_loss: 3.9268 - y1_output_root_mean_squared_error: 1.4146 - y2_output_root_mean_squared_error: 1.9816 - val_loss: 6.6597 - val_y1_output_loss: 2.5536 - val_y2_output_loss: 4.1061 - val_y1_output_root_mean_squared_error: 1.5980 - val_y2_output_root_mean_squared_error: 2.0263
# Epoch 48/500
# 62/62 [==============================] - 0s 5ms/step - loss: 7.0680 - y1_output_loss: 2.1501 - y2_output_loss: 4.9178 - y1_output_root_mean_squared_error: 1.4663 - y2_output_root_mean_squared_error: 2.2176 - val_loss: 6.0203 - val_y1_output_loss: 2.0661 - val_y2_output_loss: 3.9542 - val_y1_output_root_mean_squared_error: 1.4374 - val_y2_output_root_mean_squared_error: 1.9885
# Epoch 49/500
# 62/62 [==============================] - 0s 4ms/step - loss: 6.2753 - y1_output_loss: 1.8896 - y2_output_loss: 4.3857 - y1_output_root_mean_squared_error: 1.3746 - y2_output_root_mean_squared_error: 2.0942 - val_loss: 21.5684 - val_y1_output_loss: 5.9790 - val_y2_output_loss: 15.5895 - val_y1_output_root_mean_squared_error: 2.4452 - val_y2_output_root_mean_squared_error: 3.9483
# Epoch 50/500
# 62/62 [==============================] - 0s 5ms/step - loss: 7.2424 - y1_output_loss: 2.1927 - y2_output_loss: 5.0497 - y1_output_root_mean_squared_error: 1.4808 - y2_output_root_mean_squared_error: 2.2472 - val_loss: 12.2678 - val_y1_output_loss: 3.0567 - val_y2_output_loss: 9.2111 - val_y1_output_root_mean_squared_error: 1.7483 - val_y2_output_root_mean_squared_error: 3.0350
# Epoch 51/500
# 62/62 [==============================] - 0s 5ms/step - loss: 6.9643 - y1_output_loss: 2.1618 - y2_output_loss: 4.8025 - y1_output_root_mean_squared_error: 1.4703 - y2_output_root_mean_squared_error: 2.1915 - val_loss: 5.9363 - val_y1_output_loss: 1.8251 - val_y2_output_loss: 4.1113 - val_y1_output_root_mean_squared_error: 1.3510 - val_y2_output_root_mean_squared_error: 2.0276
# Epoch 52/500
# 62/62 [==============================] - 0s 4ms/step - loss: 21.0948 - y1_output_loss: 6.6267 - y2_output_loss: 14.4681 - y1_output_root_mean_squared_error: 2.5742 - y2_output_root_mean_squared_error: 3.8037 - val_loss: 6.4477 - val_y1_output_loss: 2.1298 - val_y2_output_loss: 4.3179 - val_y1_output_root_mean_squared_error: 1.4594 - val_y2_output_root_mean_squared_error: 2.0780
# Epoch 53/500
# 62/62 [==============================] - 0s 4ms/step - loss: 6.4361 - y1_output_loss: 2.0051 - y2_output_loss: 4.4310 - y1_output_root_mean_squared_error: 1.4160 - y2_output_root_mean_squared_error: 2.1050 - val_loss: 5.5389 - val_y1_output_loss: 1.6025 - val_y2_output_loss: 3.9364 - val_y1_output_root_mean_squared_error: 1.2659 - val_y2_output_root_mean_squared_error: 1.9840
# Epoch 54/500
# 62/62 [==============================] - 0s 6ms/step - loss: 5.7496 - y1_output_loss: 1.7652 - y2_output_loss: 3.9843 - y1_output_root_mean_squared_error: 1.3286 - y2_output_root_mean_squared_error: 1.9961 - val_loss: 46.4522 - val_y1_output_loss: 13.9868 - val_y2_output_loss: 32.4654 - val_y1_output_root_mean_squared_error: 3.7399 - val_y2_output_root_mean_squared_error: 5.6978
# Epoch 55/500
# 62/62 [==============================] - 0s 5ms/step - loss: 5.7694 - y1_output_loss: 1.8267 - y2_output_loss: 3.9427 - y1_output_root_mean_squared_error: 1.3515 - y2_output_root_mean_squared_error: 1.9856 - val_loss: 6.5356 - val_y1_output_loss: 2.0707 - val_y2_output_loss: 4.4648 - val_y1_output_root_mean_squared_error: 1.4390 - val_y2_output_root_mean_squared_error: 2.1130
# Epoch 56/500
# 62/62 [==============================] - 0s 6ms/step - loss: 6.5341 - y1_output_loss: 1.8992 - y2_output_loss: 4.6349 - y1_output_root_mean_squared_error: 1.3781 - y2_output_root_mean_squared_error: 2.1529 - val_loss: 5.8674 - val_y1_output_loss: 1.8240 - val_y2_output_loss: 4.0434 - val_y1_output_root_mean_squared_error: 1.3506 - val_y2_output_root_mean_squared_error: 2.0108
# Epoch 57/500
# 62/62 [==============================] - 0s 7ms/step - loss: 4.8818 - y1_output_loss: 1.4259 - y2_output_loss: 3.4559 - y1_output_root_mean_squared_error: 1.1941 - y2_output_root_mean_squared_error: 1.8590 - val_loss: 9.2322 - val_y1_output_loss: 1.9007 - val_y2_output_loss: 7.3315 - val_y1_output_root_mean_squared_error: 1.3787 - val_y2_output_root_mean_squared_error: 2.7077
# Epoch 58/500
# 62/62 [==============================] - 0s 7ms/step - loss: 4.6789 - y1_output_loss: 1.3686 - y2_output_loss: 3.3103 - y1_output_root_mean_squared_error: 1.1699 - y2_output_root_mean_squared_error: 1.8194 - val_loss: 5.3952 - val_y1_output_loss: 1.6559 - val_y2_output_loss: 3.7393 - val_y1_output_root_mean_squared_error: 1.2868 - val_y2_output_root_mean_squared_error: 1.9337
# Epoch 59/500
# 62/62 [==============================] - 1s 12ms/step - loss: 6.4406 - y1_output_loss: 1.8611 - y2_output_loss: 4.5796 - y1_output_root_mean_squared_error: 1.3642 - y2_output_root_mean_squared_error: 2.1400 - val_loss: 7.6448 - val_y1_output_loss: 1.5075 - val_y2_output_loss: 6.1373 - val_y1_output_root_mean_squared_error: 1.2278 - val_y2_output_root_mean_squared_error: 2.4774
# Epoch 60/500
# 62/62 [==============================] - 1s 10ms/step - loss: 6.6239 - y1_output_loss: 1.8102 - y2_output_loss: 4.8137 - y1_output_root_mean_squared_error: 1.3454 - y2_output_root_mean_squared_error: 2.1940 - val_loss: 38.2041 - val_y1_output_loss: 7.2131 - val_y2_output_loss: 30.9909 - val_y1_output_root_mean_squared_error: 2.6857 - val_y2_output_root_mean_squared_error: 5.5670
# Epoch 61/500
# 62/62 [==============================] - 1s 12ms/step - loss: 6.0764 - y1_output_loss: 1.8147 - y2_output_loss: 4.2617 - y1_output_root_mean_squared_error: 1.3471 - y2_output_root_mean_squared_error: 2.0644 - val_loss: 4.8980 - val_y1_output_loss: 1.4600 - val_y2_output_loss: 3.4380 - val_y1_output_root_mean_squared_error: 1.2083 - val_y2_output_root_mean_squared_error: 1.8542
# Epoch 62/500
# 62/62 [==============================] - 1s 18ms/step - loss: 5.0819 - y1_output_loss: 1.4724 - y2_output_loss: 3.6095 - y1_output_root_mean_squared_error: 1.2134 - y2_output_root_mean_squared_error: 1.8999 - val_loss: 10.2809 - val_y1_output_loss: 2.2185 - val_y2_output_loss: 8.0624 - val_y1_output_root_mean_squared_error: 1.4895 - val_y2_output_root_mean_squared_error: 2.8394
# Epoch 63/500
# 62/62 [==============================] - 1s 19ms/step - loss: 4.6547 - y1_output_loss: 1.3248 - y2_output_loss: 3.3299 - y1_output_root_mean_squared_error: 1.1510 - y2_output_root_mean_squared_error: 1.8248 - val_loss: 5.2190 - val_y1_output_loss: 1.2977 - val_y2_output_loss: 3.9214 - val_y1_output_root_mean_squared_error: 1.1392 - val_y2_output_root_mean_squared_error: 1.9802
# Epoch 64/500
# 62/62 [==============================] - 1s 22ms/step - loss: 3.9439 - y1_output_loss: 1.2230 - y2_output_loss: 2.7209 - y1_output_root_mean_squared_error: 1.1059 - y2_output_root_mean_squared_error: 1.6495 - val_loss: 5.0329 - val_y1_output_loss: 1.7555 - val_y2_output_loss: 3.2775 - val_y1_output_root_mean_squared_error: 1.3249 - val_y2_output_root_mean_squared_error: 1.8104
# Epoch 65/500
# 62/62 [==============================] - 1s 19ms/step - loss: 4.9855 - y1_output_loss: 1.4836 - y2_output_loss: 3.5019 - y1_output_root_mean_squared_error: 1.2180 - y2_output_root_mean_squared_error: 1.8713 - val_loss: 4.4136 - val_y1_output_loss: 1.4081 - val_y2_output_loss: 3.0055 - val_y1_output_root_mean_squared_error: 1.1867 - val_y2_output_root_mean_squared_error: 1.7336
# Epoch 66/500
# 62/62 [==============================] - 2s 34ms/step - loss: 3.9981 - y1_output_loss: 1.1340 - y2_output_loss: 2.8640 - y1_output_root_mean_squared_error: 1.0649 - y2_output_root_mean_squared_error: 1.6923 - val_loss: 4.3195 - val_y1_output_loss: 1.1717 - val_y2_output_loss: 3.1478 - val_y1_output_root_mean_squared_error: 1.0825 - val_y2_output_root_mean_squared_error: 1.7742
# Epoch 67/500
# 62/62 [==============================] - 2s 35ms/step - loss: 4.5167 - y1_output_loss: 1.3015 - y2_output_loss: 3.2152 - y1_output_root_mean_squared_error: 1.1408 - y2_output_root_mean_squared_error: 1.7931 - val_loss: 7.8164 - val_y1_output_loss: 1.8095 - val_y2_output_loss: 6.0068 - val_y1_output_root_mean_squared_error: 1.3452 - val_y2_output_root_mean_squared_error: 2.4509
# Epoch 68/500
# 62/62 [==============================] - 2s 32ms/step - loss: 4.9073 - y1_output_loss: 1.4158 - y2_output_loss: 3.4916 - y1_output_root_mean_squared_error: 1.1899 - y2_output_root_mean_squared_error: 1.8686 - val_loss: 4.4259 - val_y1_output_loss: 1.2575 - val_y2_output_loss: 3.1684 - val_y1_output_root_mean_squared_error: 1.1214 - val_y2_output_root_mean_squared_error: 1.7800
# Epoch 69/500
# 62/62 [==============================] - 2s 28ms/step - loss: 4.3767 - y1_output_loss: 1.2214 - y2_output_loss: 3.1553 - y1_output_root_mean_squared_error: 1.1052 - y2_output_root_mean_squared_error: 1.7763 - val_loss: 7.2272 - val_y1_output_loss: 2.5186 - val_y2_output_loss: 4.7087 - val_y1_output_root_mean_squared_error: 1.5870 - val_y2_output_root_mean_squared_error: 2.1699
# Epoch 70/500
# 62/62 [==============================] - 2s 26ms/step - loss: 5.0908 - y1_output_loss: 1.4391 - y2_output_loss: 3.6517 - y1_output_root_mean_squared_error: 1.1996 - y2_output_root_mean_squared_error: 1.9109 - val_loss: 4.1121 - val_y1_output_loss: 1.1944 - val_y2_output_loss: 2.9177 - val_y1_output_root_mean_squared_error: 1.0929 - val_y2_output_root_mean_squared_error: 1.7081
# Epoch 71/500
# 62/62 [==============================] - 2s 27ms/step - loss: 4.2747 - y1_output_loss: 1.1552 - y2_output_loss: 3.1195 - y1_output_root_mean_squared_error: 1.0748 - y2_output_root_mean_squared_error: 1.7662 - val_loss: 6.4982 - val_y1_output_loss: 1.7767 - val_y2_output_loss: 4.7215 - val_y1_output_root_mean_squared_error: 1.3329 - val_y2_output_root_mean_squared_error: 2.1729
# Epoch 72/500
# 62/62 [==============================] - 1s 21ms/step - loss: 3.9575 - y1_output_loss: 1.1657 - y2_output_loss: 2.7918 - y1_output_root_mean_squared_error: 1.0797 - y2_output_root_mean_squared_error: 1.6709 - val_loss: 6.5916 - val_y1_output_loss: 1.6532 - val_y2_output_loss: 4.9384 - val_y1_output_root_mean_squared_error: 1.2858 - val_y2_output_root_mean_squared_error: 2.2222
# Epoch 73/500
# 62/62 [==============================] - 2s 29ms/step - loss: 5.4501 - y1_output_loss: 1.4662 - y2_output_loss: 3.9839 - y1_output_root_mean_squared_error: 1.2109 - y2_output_root_mean_squared_error: 1.9960 - val_loss: 4.2750 - val_y1_output_loss: 1.0699 - val_y2_output_loss: 3.2051 - val_y1_output_root_mean_squared_error: 1.0344 - val_y2_output_root_mean_squared_error: 1.7903
# Epoch 74/500
# 62/62 [==============================] - 2s 24ms/step - loss: 4.3453 - y1_output_loss: 1.1907 - y2_output_loss: 3.1546 - y1_output_root_mean_squared_error: 1.0912 - y2_output_root_mean_squared_error: 1.7761 - val_loss: 5.3012 - val_y1_output_loss: 1.5627 - val_y2_output_loss: 3.7385 - val_y1_output_root_mean_squared_error: 1.2501 - val_y2_output_root_mean_squared_error: 1.9335
# Epoch 75/500
# 62/62 [==============================] - 1s 22ms/step - loss: 3.2608 - y1_output_loss: 0.9111 - y2_output_loss: 2.3497 - y1_output_root_mean_squared_error: 0.9545 - y2_output_root_mean_squared_error: 1.5329 - val_loss: 4.7821 - val_y1_output_loss: 1.0346 - val_y2_output_loss: 3.7475 - val_y1_output_root_mean_squared_error: 1.0172 - val_y2_output_root_mean_squared_error: 1.9358
# Epoch 76/500
# 62/62 [==============================] - 1s 22ms/step - loss: 4.4293 - y1_output_loss: 1.2061 - y2_output_loss: 3.2232 - y1_output_root_mean_squared_error: 1.0982 - y2_output_root_mean_squared_error: 1.7953 - val_loss: 5.5665 - val_y1_output_loss: 1.5890 - val_y2_output_loss: 3.9775 - val_y1_output_root_mean_squared_error: 1.2605 - val_y2_output_root_mean_squared_error: 1.9944
# Epoch 77/500
# 62/62 [==============================] - 2s 26ms/step - loss: 3.1108 - y1_output_loss: 1.0000 - y2_output_loss: 2.1107 - y1_output_root_mean_squared_error: 1.0000 - y2_output_root_mean_squared_error: 1.4528 - val_loss: 7.2865 - val_y1_output_loss: 1.1673 - val_y2_output_loss: 6.1192 - val_y1_output_root_mean_squared_error: 1.0804 - val_y2_output_root_mean_squared_error: 2.4737
# Epoch 78/500
# 62/62 [==============================] - 1s 23ms/step - loss: 3.9770 - y1_output_loss: 1.0649 - y2_output_loss: 2.9122 - y1_output_root_mean_squared_error: 1.0319 - y2_output_root_mean_squared_error: 1.7065 - val_loss: 7.0811 - val_y1_output_loss: 2.3383 - val_y2_output_loss: 4.7427 - val_y1_output_root_mean_squared_error: 1.5292 - val_y2_output_root_mean_squared_error: 2.1778
# Epoch 79/500
# 62/62 [==============================] - 2s 34ms/step - loss: 4.0138 - y1_output_loss: 1.0506 - y2_output_loss: 2.9632 - y1_output_root_mean_squared_error: 1.0250 - y2_output_root_mean_squared_error: 1.7214 - val_loss: 3.7290 - val_y1_output_loss: 0.9616 - val_y2_output_loss: 2.7674 - val_y1_output_root_mean_squared_error: 0.9806 - val_y2_output_root_mean_squared_error: 1.6636
# Epoch 80/500
# 62/62 [==============================] - 2s 31ms/step - loss: 5.8716 - y1_output_loss: 1.6506 - y2_output_loss: 4.2211 - y1_output_root_mean_squared_error: 1.2847 - y2_output_root_mean_squared_error: 2.0545 - val_loss: 3.5356 - val_y1_output_loss: 0.9934 - val_y2_output_loss: 2.5422 - val_y1_output_root_mean_squared_error: 0.9967 - val_y2_output_root_mean_squared_error: 1.5944
# Epoch 81/500
# 62/62 [==============================] - 2s 31ms/step - loss: 3.4085 - y1_output_loss: 0.9641 - y2_output_loss: 2.4444 - y1_output_root_mean_squared_error: 0.9819 - y2_output_root_mean_squared_error: 1.5635 - val_loss: 4.7834 - val_y1_output_loss: 1.4872 - val_y2_output_loss: 3.2961 - val_y1_output_root_mean_squared_error: 1.2195 - val_y2_output_root_mean_squared_error: 1.8155
# Epoch 82/500
# 62/62 [==============================] - 1s 18ms/step - loss: 3.1256 - y1_output_loss: 0.8874 - y2_output_loss: 2.2382 - y1_output_root_mean_squared_error: 0.9420 - y2_output_root_mean_squared_error: 1.4961 - val_loss: 3.1848 - val_y1_output_loss: 0.8059 - val_y2_output_loss: 2.3789 - val_y1_output_root_mean_squared_error: 0.8977 - val_y2_output_root_mean_squared_error: 1.5424
# Epoch 83/500
# 62/62 [==============================] - 1s 15ms/step - loss: 3.1324 - y1_output_loss: 0.8548 - y2_output_loss: 2.2776 - y1_output_root_mean_squared_error: 0.9246 - y2_output_root_mean_squared_error: 1.5092 - val_loss: 3.4813 - val_y1_output_loss: 1.0269 - val_y2_output_loss: 2.4544 - val_y1_output_root_mean_squared_error: 1.0134 - val_y2_output_root_mean_squared_error: 1.5666
# Epoch 84/500
# 62/62 [==============================] - 1s 11ms/step - loss: 2.9086 - y1_output_loss: 0.8448 - y2_output_loss: 2.0638 - y1_output_root_mean_squared_error: 0.9191 - y2_output_root_mean_squared_error: 1.4366 - val_loss: 4.3314 - val_y1_output_loss: 1.2273 - val_y2_output_loss: 3.1042 - val_y1_output_root_mean_squared_error: 1.1078 - val_y2_output_root_mean_squared_error: 1.7619
# Epoch 85/500
# 62/62 [==============================] - 1s 11ms/step - loss: 4.0419 - y1_output_loss: 1.1390 - y2_output_loss: 2.9029 - y1_output_root_mean_squared_error: 1.0672 - y2_output_root_mean_squared_error: 1.7038 - val_loss: 3.3435 - val_y1_output_loss: 1.0294 - val_y2_output_loss: 2.3140 - val_y1_output_root_mean_squared_error: 1.0146 - val_y2_output_root_mean_squared_error: 1.5212
# Epoch 86/500
# 62/62 [==============================] - 1s 16ms/step - loss: 3.3985 - y1_output_loss: 1.0235 - y2_output_loss: 2.3750 - y1_output_root_mean_squared_error: 1.0117 - y2_output_root_mean_squared_error: 1.5411 - val_loss: 3.1559 - val_y1_output_loss: 0.7220 - val_y2_output_loss: 2.4340 - val_y1_output_root_mean_squared_error: 0.8497 - val_y2_output_root_mean_squared_error: 1.5601
# Epoch 87/500
# 62/62 [==============================] - 1s 15ms/step - loss: 3.3637 - y1_output_loss: 0.8898 - y2_output_loss: 2.4739 - y1_output_root_mean_squared_error: 0.9433 - y2_output_root_mean_squared_error: 1.5729 - val_loss: 12.9758 - val_y1_output_loss: 4.1523 - val_y2_output_loss: 8.8235 - val_y1_output_root_mean_squared_error: 2.0377 - val_y2_output_root_mean_squared_error: 2.9704
# Epoch 88/500
# 62/62 [==============================] - 1s 12ms/step - loss: 3.9004 - y1_output_loss: 1.0238 - y2_output_loss: 2.8767 - y1_output_root_mean_squared_error: 1.0118 - y2_output_root_mean_squared_error: 1.6961 - val_loss: 3.6974 - val_y1_output_loss: 0.8217 - val_y2_output_loss: 2.8757 - val_y1_output_root_mean_squared_error: 0.9065 - val_y2_output_root_mean_squared_error: 1.6958
# Epoch 89/500
# 62/62 [==============================] - 1s 16ms/step - loss: 2.9790 - y1_output_loss: 0.9172 - y2_output_loss: 2.0618 - y1_output_root_mean_squared_error: 0.9577 - y2_output_root_mean_squared_error: 1.4359 - val_loss: 4.7120 - val_y1_output_loss: 1.0120 - val_y2_output_loss: 3.7000 - val_y1_output_root_mean_squared_error: 1.0060 - val_y2_output_root_mean_squared_error: 1.9235
# Epoch 90/500
# 62/62 [==============================] - 2s 28ms/step - loss: 2.5515 - y1_output_loss: 0.5964 - y2_output_loss: 1.9551 - y1_output_root_mean_squared_error: 0.7723 - y2_output_root_mean_squared_error: 1.3983 - val_loss: 4.0466 - val_y1_output_loss: 0.6929 - val_y2_output_loss: 3.3538 - val_y1_output_root_mean_squared_error: 0.8324 - val_y2_output_root_mean_squared_error: 1.8313
# Epoch 91/500
# 62/62 [==============================] - 2s 25ms/step - loss: 3.0077 - y1_output_loss: 0.8158 - y2_output_loss: 2.1920 - y1_output_root_mean_squared_error: 0.9032 - y2_output_root_mean_squared_error: 1.4805 - val_loss: 2.6595 - val_y1_output_loss: 0.5427 - val_y2_output_loss: 2.1167 - val_y1_output_root_mean_squared_error: 0.7367 - val_y2_output_root_mean_squared_error: 1.4549
# Epoch 92/500
# 62/62 [==============================] - 2s 24ms/step - loss: 2.9498 - y1_output_loss: 0.8969 - y2_output_loss: 2.0529 - y1_output_root_mean_squared_error: 0.9470 - y2_output_root_mean_squared_error: 1.4328 - val_loss: 3.7136 - val_y1_output_loss: 0.6994 - val_y2_output_loss: 3.0142 - val_y1_output_root_mean_squared_error: 0.8363 - val_y2_output_root_mean_squared_error: 1.7361
# Epoch 93/500
# 62/62 [==============================] - 1s 20ms/step - loss: 2.8052 - y1_output_loss: 0.7826 - y2_output_loss: 2.0227 - y1_output_root_mean_squared_error: 0.8846 - y2_output_root_mean_squared_error: 1.4222 - val_loss: 3.1716 - val_y1_output_loss: 0.5724 - val_y2_output_loss: 2.5992 - val_y1_output_root_mean_squared_error: 0.7566 - val_y2_output_root_mean_squared_error: 1.6122
# Epoch 94/500
# 62/62 [==============================] - 2s 31ms/step - loss: 2.6324 - y1_output_loss: 0.6849 - y2_output_loss: 1.9475 - y1_output_root_mean_squared_error: 0.8276 - y2_output_root_mean_squared_error: 1.3955 - val_loss: 3.0168 - val_y1_output_loss: 0.4887 - val_y2_output_loss: 2.5280 - val_y1_output_root_mean_squared_error: 0.6991 - val_y2_output_root_mean_squared_error: 1.5900
# Epoch 95/500
# 62/62 [==============================] - 2s 27ms/step - loss: 2.8534 - y1_output_loss: 0.8085 - y2_output_loss: 2.0449 - y1_output_root_mean_squared_error: 0.8992 - y2_output_root_mean_squared_error: 1.4300 - val_loss: 4.7833 - val_y1_output_loss: 1.4611 - val_y2_output_loss: 3.3222 - val_y1_output_root_mean_squared_error: 1.2088 - val_y2_output_root_mean_squared_error: 1.8227
# Epoch 96/500
# 62/62 [==============================] - 3s 45ms/step - loss: 3.4045 - y1_output_loss: 0.9318 - y2_output_loss: 2.4727 - y1_output_root_mean_squared_error: 0.9653 - y2_output_root_mean_squared_error: 1.5725 - val_loss: 4.2828 - val_y1_output_loss: 0.7451 - val_y2_output_loss: 3.5377 - val_y1_output_root_mean_squared_error: 0.8632 - val_y2_output_root_mean_squared_error: 1.8809
# Epoch 97/500
# 62/62 [==============================] - 2s 26ms/step - loss: 2.7596 - y1_output_loss: 0.7090 - y2_output_loss: 2.0506 - y1_output_root_mean_squared_error: 0.8420 - y2_output_root_mean_squared_error: 1.4320 - val_loss: 2.8954 - val_y1_output_loss: 0.7546 - val_y2_output_loss: 2.1408 - val_y1_output_root_mean_squared_error: 0.8687 - val_y2_output_root_mean_squared_error: 1.4632
# Epoch 98/500
# 62/62 [==============================] - 2s 33ms/step - loss: 3.2560 - y1_output_loss: 0.8669 - y2_output_loss: 2.3891 - y1_output_root_mean_squared_error: 0.9311 - y2_output_root_mean_squared_error: 1.5457 - val_loss: 6.9464 - val_y1_output_loss: 1.1535 - val_y2_output_loss: 5.7929 - val_y1_output_root_mean_squared_error: 1.0740 - val_y2_output_root_mean_squared_error: 2.4068
# Epoch 99/500
# 62/62 [==============================] - 2s 35ms/step - loss: 2.8668 - y1_output_loss: 0.6497 - y2_output_loss: 2.2170 - y1_output_root_mean_squared_error: 0.8061 - y2_output_root_mean_squared_error: 1.4890 - val_loss: 3.5484 - val_y1_output_loss: 0.6150 - val_y2_output_loss: 2.9334 - val_y1_output_root_mean_squared_error: 0.7842 - val_y2_output_root_mean_squared_error: 1.7127
# Epoch 100/500
# 62/62 [==============================] - 1s 24ms/step - loss: 2.7069 - y1_output_loss: 0.7449 - y2_output_loss: 1.9620 - y1_output_root_mean_squared_error: 0.8631 - y2_output_root_mean_squared_error: 1.4007 - val_loss: 6.6018 - val_y1_output_loss: 1.0297 - val_y2_output_loss: 5.5722 - val_y1_output_root_mean_squared_error: 1.0147 - val_y2_output_root_mean_squared_error: 2.3605
# Epoch 101/500
# 62/62 [==============================] - 2s 31ms/step - loss: 2.6975 - y1_output_loss: 0.6538 - y2_output_loss: 2.0437 - y1_output_root_mean_squared_error: 0.8086 - y2_output_root_mean_squared_error: 1.4296 - val_loss: 3.6203 - val_y1_output_loss: 1.0963 - val_y2_output_loss: 2.5240 - val_y1_output_root_mean_squared_error: 1.0470 - val_y2_output_root_mean_squared_error: 1.5887
# Epoch 102/500
# 62/62 [==============================] - 2s 30ms/step - loss: 2.8035 - y1_output_loss: 0.7524 - y2_output_loss: 2.0511 - y1_output_root_mean_squared_error: 0.8674 - y2_output_root_mean_squared_error: 1.4322 - val_loss: 3.0825 - val_y1_output_loss: 0.6195 - val_y2_output_loss: 2.4630 - val_y1_output_root_mean_squared_error: 0.7871 - val_y2_output_root_mean_squared_error: 1.5694
# Epoch 103/500
# 62/62 [==============================] - 1s 16ms/step - loss: 2.9814 - y1_output_loss: 0.7793 - y2_output_loss: 2.2021 - y1_output_root_mean_squared_error: 0.8828 - y2_output_root_mean_squared_error: 1.4840 - val_loss: 3.3489 - val_y1_output_loss: 0.9645 - val_y2_output_loss: 2.3845 - val_y1_output_root_mean_squared_error: 0.9821 - val_y2_output_root_mean_squared_error: 1.5442
# Epoch 104/500
# 62/62 [==============================] - 1s 15ms/step - loss: 2.7296 - y1_output_loss: 0.6334 - y2_output_loss: 2.0962 - y1_output_root_mean_squared_error: 0.7958 - y2_output_root_mean_squared_error: 1.4478 - val_loss: 2.6241 - val_y1_output_loss: 0.6077 - val_y2_output_loss: 2.0164 - val_y1_output_root_mean_squared_error: 0.7796 - val_y2_output_root_mean_squared_error: 1.4200
# Epoch 105/500
# 62/62 [==============================] - 1s 18ms/step - loss: 2.5723 - y1_output_loss: 0.6558 - y2_output_loss: 1.9165 - y1_output_root_mean_squared_error: 0.8098 - y2_output_root_mean_squared_error: 1.3844 - val_loss: 6.9137 - val_y1_output_loss: 1.2278 - val_y2_output_loss: 5.6860 - val_y1_output_root_mean_squared_error: 1.1080 - val_y2_output_root_mean_squared_error: 2.3845
# Epoch 106/500
# 62/62 [==============================] - 1s 11ms/step - loss: 3.2862 - y1_output_loss: 0.7795 - y2_output_loss: 2.5067 - y1_output_root_mean_squared_error: 0.8829 - y2_output_root_mean_squared_error: 1.5833 - val_loss: 8.4086 - val_y1_output_loss: 1.2535 - val_y2_output_loss: 7.1551 - val_y1_output_root_mean_squared_error: 1.1196 - val_y2_output_root_mean_squared_error: 2.6749
# Epoch 107/500
# 62/62 [==============================] - 1s 15ms/step - loss: 3.1118 - y1_output_loss: 0.8311 - y2_output_loss: 2.2808 - y1_output_root_mean_squared_error: 0.9116 - y2_output_root_mean_squared_error: 1.5102 - val_loss: 10.3572 - val_y1_output_loss: 1.3537 - val_y2_output_loss: 9.0035 - val_y1_output_root_mean_squared_error: 1.1635 - val_y2_output_root_mean_squared_error: 3.0006
# Epoch 108/500
# 62/62 [==============================] - 1s 15ms/step - loss: 3.1940 - y1_output_loss: 0.8836 - y2_output_loss: 2.3104 - y1_output_root_mean_squared_error: 0.9400 - y2_output_root_mean_squared_error: 1.5200 - val_loss: 2.4403 - val_y1_output_loss: 0.5232 - val_y2_output_loss: 1.9171 - val_y1_output_root_mean_squared_error: 0.7233 - val_y2_output_root_mean_squared_error: 1.3846
# Epoch 109/500
# 62/62 [==============================] - 1s 13ms/step - loss: 2.7870 - y1_output_loss: 0.7507 - y2_output_loss: 2.0363 - y1_output_root_mean_squared_error: 0.8664 - y2_output_root_mean_squared_error: 1.4270 - val_loss: 5.1884 - val_y1_output_loss: 1.0347 - val_y2_output_loss: 4.1537 - val_y1_output_root_mean_squared_error: 1.0172 - val_y2_output_root_mean_squared_error: 2.0381
# Epoch 110/500
# 62/62 [==============================] - 1s 17ms/step - loss: 2.6706 - y1_output_loss: 0.6198 - y2_output_loss: 2.0508 - y1_output_root_mean_squared_error: 0.7873 - y2_output_root_mean_squared_error: 1.4321 - val_loss: 2.8629 - val_y1_output_loss: 0.7554 - val_y2_output_loss: 2.1075 - val_y1_output_root_mean_squared_error: 0.8691 - val_y2_output_root_mean_squared_error: 1.4517
# Epoch 111/500
# 62/62 [==============================] - 1s 15ms/step - loss: 2.5590 - y1_output_loss: 0.6717 - y2_output_loss: 1.8872 - y1_output_root_mean_squared_error: 0.8196 - y2_output_root_mean_squared_error: 1.3738 - val_loss: 3.5235 - val_y1_output_loss: 0.7946 - val_y2_output_loss: 2.7289 - val_y1_output_root_mean_squared_error: 0.8914 - val_y2_output_root_mean_squared_error: 1.6519
# Epoch 112/500
# 62/62 [==============================] - 1s 20ms/step - loss: 2.0345 - y1_output_loss: 0.5611 - y2_output_loss: 1.4734 - y1_output_root_mean_squared_error: 0.7491 - y2_output_root_mean_squared_error: 1.2138 - val_loss: 3.0082 - val_y1_output_loss: 0.8599 - val_y2_output_loss: 2.1483 - val_y1_output_root_mean_squared_error: 0.9273 - val_y2_output_root_mean_squared_error: 1.4657
# Epoch 113/500
# 62/62 [==============================] - 1s 15ms/step - loss: 2.1799 - y1_output_loss: 0.5124 - y2_output_loss: 1.6675 - y1_output_root_mean_squared_error: 0.7158 - y2_output_root_mean_squared_error: 1.2913 - val_loss: 12.2974 - val_y1_output_loss: 3.9381 - val_y2_output_loss: 8.3593 - val_y1_output_root_mean_squared_error: 1.9845 - val_y2_output_root_mean_squared_error: 2.8912
# Epoch 114/500
# 62/62 [==============================] - 1s 15ms/step - loss: 21.0327 - y1_output_loss: 7.8655 - y2_output_loss: 13.1672 - y1_output_root_mean_squared_error: 2.8045 - y2_output_root_mean_squared_error: 3.6287 - val_loss: 6.3343 - val_y1_output_loss: 0.9627 - val_y2_output_loss: 5.3716 - val_y1_output_root_mean_squared_error: 0.9812 - val_y2_output_root_mean_squared_error: 2.3177
# Epoch 115/500
# 62/62 [==============================] - 1s 17ms/step - loss: 2.7764 - y1_output_loss: 0.6611 - y2_output_loss: 2.1153 - y1_output_root_mean_squared_error: 0.8131 - y2_output_root_mean_squared_error: 1.4544 - val_loss: 2.5731 - val_y1_output_loss: 0.5634 - val_y2_output_loss: 2.0096 - val_y1_output_root_mean_squared_error: 0.7506 - val_y2_output_root_mean_squared_error: 1.4176
# Epoch 116/500
# 62/62 [==============================] - 1s 14ms/step - loss: 2.3949 - y1_output_loss: 0.6340 - y2_output_loss: 1.7609 - y1_output_root_mean_squared_error: 0.7963 - y2_output_root_mean_squared_error: 1.3270 - val_loss: 12.3347 - val_y1_output_loss: 1.4491 - val_y2_output_loss: 10.8856 - val_y1_output_root_mean_squared_error: 1.2038 - val_y2_output_root_mean_squared_error: 3.2993
# Epoch 117/500
# 62/62 [==============================] - 0s 8ms/step - loss: 2.7377 - y1_output_loss: 0.6492 - y2_output_loss: 2.0885 - y1_output_root_mean_squared_error: 0.8057 - y2_output_root_mean_squared_error: 1.4452 - val_loss: 3.3178 - val_y1_output_loss: 0.7936 - val_y2_output_loss: 2.5242 - val_y1_output_root_mean_squared_error: 0.8908 - val_y2_output_root_mean_squared_error: 1.5888
# Epoch 118/500
# 62/62 [==============================] - 1s 11ms/step - loss: 2.6848 - y1_output_loss: 0.7045 - y2_output_loss: 1.9803 - y1_output_root_mean_squared_error: 0.8394 - y2_output_root_mean_squared_error: 1.4072 - val_loss: 3.5485 - val_y1_output_loss: 0.7717 - val_y2_output_loss: 2.7768 - val_y1_output_root_mean_squared_error: 0.8785 - val_y2_output_root_mean_squared_error: 1.6664
# Epoch 119/500
# 62/62 [==============================] - 1s 11ms/step - loss: 2.8747 - y1_output_loss: 0.7543 - y2_output_loss: 2.1204 - y1_output_root_mean_squared_error: 0.8685 - y2_output_root_mean_squared_error: 1.4562 - val_loss: 2.5741 - val_y1_output_loss: 0.4454 - val_y2_output_loss: 2.1287 - val_y1_output_root_mean_squared_error: 0.6674 - val_y2_output_root_mean_squared_error: 1.4590
# Epoch 120/500
# 62/62 [==============================] - 1s 9ms/step - loss: 1.8900 - y1_output_loss: 0.4758 - y2_output_loss: 1.4142 - y1_output_root_mean_squared_error: 0.6897 - y2_output_root_mean_squared_error: 1.1892 - val_loss: 3.0509 - val_y1_output_loss: 0.6004 - val_y2_output_loss: 2.4505 - val_y1_output_root_mean_squared_error: 0.7749 - val_y2_output_root_mean_squared_error: 1.5654
# Epoch 121/500
# 62/62 [==============================] - 1s 9ms/step - loss: 2.1078 - y1_output_loss: 0.4613 - y2_output_loss: 1.6466 - y1_output_root_mean_squared_error: 0.6792 - y2_output_root_mean_squared_error: 1.2832 - val_loss: 2.1549 - val_y1_output_loss: 0.5155 - val_y2_output_loss: 1.6394 - val_y1_output_root_mean_squared_error: 0.7180 - val_y2_output_root_mean_squared_error: 1.2804
# Epoch 122/500
# ...
# Epoch 461/500
# 62/62 [==============================] - 0s 7ms/step - loss: 0.3678 - y1_output_loss: 0.1141 - y2_output_loss: 0.2536 - y1_output_root_mean_squared_error: 0.3378 - y2_output_root_mean_squared_error: 0.5036 - val_loss: 0.8324 - val_y1_output_loss: 0.2425 - val_y2_output_loss: 0.5900 - val_y1_output_root_mean_squared_error: 0.4924 - val_y2_output_root_mean_squared_error: 0.7681
# Epoch 462/500
# 62/62 [==============================] - 0s 7ms/step - loss: 0.5180 - y1_output_loss: 0.1327 - y2_output_loss: 0.3853 - y1_output_root_mean_squared_error: 0.3643 - y2_output_root_mean_squared_error: 0.6207 - val_loss: 1.0713 - val_y1_output_loss: 0.3498 - val_y2_output_loss: 0.7216 - val_y1_output_root_mean_squared_error: 0.5914 - val_y2_output_root_mean_squared_error: 0.8494
# Epoch 463/500
# 62/62 [==============================] - 0s 7ms/step - loss: 0.4015 - y1_output_loss: 0.1270 - y2_output_loss: 0.2745 - y1_output_root_mean_squared_error: 0.3564 - y2_output_root_mean_squared_error: 0.5239 - val_loss: 0.8840 - val_y1_output_loss: 0.2224 - val_y2_output_loss: 0.6617 - val_y1_output_root_mean_squared_error: 0.4716 - val_y2_output_root_mean_squared_error: 0.8134
# Epoch 464/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4026 - y1_output_loss: 0.1281 - y2_output_loss: 0.2744 - y1_output_root_mean_squared_error: 0.3580 - y2_output_root_mean_squared_error: 0.5239 - val_loss: 1.0210 - val_y1_output_loss: 0.2163 - val_y2_output_loss: 0.8047 - val_y1_output_root_mean_squared_error: 0.4651 - val_y2_output_root_mean_squared_error: 0.8970
# Epoch 465/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4436 - y1_output_loss: 0.1286 - y2_output_loss: 0.3150 - y1_output_root_mean_squared_error: 0.3586 - y2_output_root_mean_squared_error: 0.5613 - val_loss: 0.8401 - val_y1_output_loss: 0.2949 - val_y2_output_loss: 0.5451 - val_y1_output_root_mean_squared_error: 0.5431 - val_y2_output_root_mean_squared_error: 0.7383
# Epoch 466/500
# 62/62 [==============================] - 0s 6ms/step - loss: 0.3878 - y1_output_loss: 0.1265 - y2_output_loss: 0.2614 - y1_output_root_mean_squared_error: 0.3556 - y2_output_root_mean_squared_error: 0.5112 - val_loss: 0.9909 - val_y1_output_loss: 0.3183 - val_y2_output_loss: 0.6726 - val_y1_output_root_mean_squared_error: 0.5642 - val_y2_output_root_mean_squared_error: 0.8201
# Epoch 467/500
# 62/62 [==============================] - 0s 7ms/step - loss: 0.3786 - y1_output_loss: 0.1204 - y2_output_loss: 0.2582 - y1_output_root_mean_squared_error: 0.3470 - y2_output_root_mean_squared_error: 0.5082 - val_loss: 0.8075 - val_y1_output_loss: 0.2188 - val_y2_output_loss: 0.5887 - val_y1_output_root_mean_squared_error: 0.4678 - val_y2_output_root_mean_squared_error: 0.7673
# Epoch 468/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3740 - y1_output_loss: 0.1325 - y2_output_loss: 0.2415 - y1_output_root_mean_squared_error: 0.3640 - y2_output_root_mean_squared_error: 0.4914 - val_loss: 0.8804 - val_y1_output_loss: 0.2110 - val_y2_output_loss: 0.6694 - val_y1_output_root_mean_squared_error: 0.4594 - val_y2_output_root_mean_squared_error: 0.8182
# Epoch 469/500
# 62/62 [==============================] - 0s 6ms/step - loss: 0.3533 - y1_output_loss: 0.1278 - y2_output_loss: 0.2255 - y1_output_root_mean_squared_error: 0.3575 - y2_output_root_mean_squared_error: 0.4749 - val_loss: 1.2280 - val_y1_output_loss: 0.2898 - val_y2_output_loss: 0.9382 - val_y1_output_root_mean_squared_error: 0.5383 - val_y2_output_root_mean_squared_error: 0.9686
# Epoch 470/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5025 - y1_output_loss: 0.1277 - y2_output_loss: 0.3747 - y1_output_root_mean_squared_error: 0.3574 - y2_output_root_mean_squared_error: 0.6122 - val_loss: 0.7752 - val_y1_output_loss: 0.1944 - val_y2_output_loss: 0.5809 - val_y1_output_root_mean_squared_error: 0.4409 - val_y2_output_root_mean_squared_error: 0.7622
# Epoch 471/500
# 62/62 [==============================] - 0s 6ms/step - loss: 0.3979 - y1_output_loss: 0.1242 - y2_output_loss: 0.2737 - y1_output_root_mean_squared_error: 0.3524 - y2_output_root_mean_squared_error: 0.5232 - val_loss: 0.8135 - val_y1_output_loss: 0.2110 - val_y2_output_loss: 0.6026 - val_y1_output_root_mean_squared_error: 0.4593 - val_y2_output_root_mean_squared_error: 0.7762
# Epoch 472/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5401 - y1_output_loss: 0.1565 - y2_output_loss: 0.3836 - y1_output_root_mean_squared_error: 0.3955 - y2_output_root_mean_squared_error: 0.6194 - val_loss: 3.1292 - val_y1_output_loss: 0.9361 - val_y2_output_loss: 2.1931 - val_y1_output_root_mean_squared_error: 0.9675 - val_y2_output_root_mean_squared_error: 1.4809
# Epoch 473/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5131 - y1_output_loss: 0.1543 - y2_output_loss: 0.3588 - y1_output_root_mean_squared_error: 0.3928 - y2_output_root_mean_squared_error: 0.5990 - val_loss: 0.9275 - val_y1_output_loss: 0.1950 - val_y2_output_loss: 0.7325 - val_y1_output_root_mean_squared_error: 0.4416 - val_y2_output_root_mean_squared_error: 0.8559
# Epoch 474/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3218 - y1_output_loss: 0.1060 - y2_output_loss: 0.2158 - y1_output_root_mean_squared_error: 0.3255 - y2_output_root_mean_squared_error: 0.4645 - val_loss: 0.8055 - val_y1_output_loss: 0.1977 - val_y2_output_loss: 0.6078 - val_y1_output_root_mean_squared_error: 0.4446 - val_y2_output_root_mean_squared_error: 0.7796
# Epoch 475/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3516 - y1_output_loss: 0.1272 - y2_output_loss: 0.2243 - y1_output_root_mean_squared_error: 0.3567 - y2_output_root_mean_squared_error: 0.4736 - val_loss: 0.7394 - val_y1_output_loss: 0.1919 - val_y2_output_loss: 0.5475 - val_y1_output_root_mean_squared_error: 0.4381 - val_y2_output_root_mean_squared_error: 0.7399
# Epoch 476/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3292 - y1_output_loss: 0.1186 - y2_output_loss: 0.2106 - y1_output_root_mean_squared_error: 0.3443 - y2_output_root_mean_squared_error: 0.4589 - val_loss: 2.9503 - val_y1_output_loss: 0.2602 - val_y2_output_loss: 2.6902 - val_y1_output_root_mean_squared_error: 0.5101 - val_y2_output_root_mean_squared_error: 1.6402
# Epoch 477/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5860 - y1_output_loss: 0.1429 - y2_output_loss: 0.4431 - y1_output_root_mean_squared_error: 0.3780 - y2_output_root_mean_squared_error: 0.6656 - val_loss: 0.8537 - val_y1_output_loss: 0.2411 - val_y2_output_loss: 0.6127 - val_y1_output_root_mean_squared_error: 0.4910 - val_y2_output_root_mean_squared_error: 0.7827
# Epoch 478/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3709 - y1_output_loss: 0.1237 - y2_output_loss: 0.2471 - y1_output_root_mean_squared_error: 0.3518 - y2_output_root_mean_squared_error: 0.4971 - val_loss: 2.2183 - val_y1_output_loss: 0.7453 - val_y2_output_loss: 1.4729 - val_y1_output_root_mean_squared_error: 0.8633 - val_y2_output_root_mean_squared_error: 1.2136
# Epoch 479/500
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4011 - y1_output_loss: 0.1350 - y2_output_loss: 0.2661 - y1_output_root_mean_squared_error: 0.3674 - y2_output_root_mean_squared_error: 0.5159 - val_loss: 0.7854 - val_y1_output_loss: 0.2224 - val_y2_output_loss: 0.5630 - val_y1_output_root_mean_squared_error: 0.4716 - val_y2_output_root_mean_squared_error: 0.7504
# Epoch 480/500
# 62/62 [==============================] - 1s 8ms/step - loss: 0.3863 - y1_output_loss: 0.1273 - y2_output_loss: 0.2590 - y1_output_root_mean_squared_error: 0.3568 - y2_output_root_mean_squared_error: 0.5089 - val_loss: 0.8174 - val_y1_output_loss: 0.2097 - val_y2_output_loss: 0.6077 - val_y1_output_root_mean_squared_error: 0.4580 - val_y2_output_root_mean_squared_error: 0.7795
# Epoch 481/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3446 - y1_output_loss: 0.1145 - y2_output_loss: 0.2301 - y1_output_root_mean_squared_error: 0.3384 - y2_output_root_mean_squared_error: 0.4797 - val_loss: 0.8094 - val_y1_output_loss: 0.1811 - val_y2_output_loss: 0.6282 - val_y1_output_root_mean_squared_error: 0.4256 - val_y2_output_root_mean_squared_error: 0.7926
# Epoch 482/500
# 62/62 [==============================] - 0s 6ms/step - loss: 0.3392 - y1_output_loss: 0.1124 - y2_output_loss: 0.2268 - y1_output_root_mean_squared_error: 0.3352 - y2_output_root_mean_squared_error: 0.4762 - val_loss: 0.7144 - val_y1_output_loss: 0.1735 - val_y2_output_loss: 0.5409 - val_y1_output_root_mean_squared_error: 0.4165 - val_y2_output_root_mean_squared_error: 0.7355
# Epoch 483/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3702 - y1_output_loss: 0.1183 - y2_output_loss: 0.2519 - y1_output_root_mean_squared_error: 0.3440 - y2_output_root_mean_squared_error: 0.5019 - val_loss: 0.7133 - val_y1_output_loss: 0.1870 - val_y2_output_loss: 0.5263 - val_y1_output_root_mean_squared_error: 0.4324 - val_y2_output_root_mean_squared_error: 0.7255
# Epoch 484/500
# 62/62 [==============================] - 0s 6ms/step - loss: 0.5063 - y1_output_loss: 0.1372 - y2_output_loss: 0.3691 - y1_output_root_mean_squared_error: 0.3704 - y2_output_root_mean_squared_error: 0.6075 - val_loss: 0.7316 - val_y1_output_loss: 0.1960 - val_y2_output_loss: 0.5356 - val_y1_output_root_mean_squared_error: 0.4428 - val_y2_output_root_mean_squared_error: 0.7318
# Epoch 485/500
# 62/62 [==============================] - 0s 6ms/step - loss: 0.3928 - y1_output_loss: 0.1199 - y2_output_loss: 0.2730 - y1_output_root_mean_squared_error: 0.3462 - y2_output_root_mean_squared_error: 0.5225 - val_loss: 0.8384 - val_y1_output_loss: 0.2533 - val_y2_output_loss: 0.5850 - val_y1_output_root_mean_squared_error: 0.5033 - val_y2_output_root_mean_squared_error: 0.7649
# Epoch 486/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5472 - y1_output_loss: 0.1597 - y2_output_loss: 0.3876 - y1_output_root_mean_squared_error: 0.3996 - y2_output_root_mean_squared_error: 0.6225 - val_loss: 0.8921 - val_y1_output_loss: 0.1939 - val_y2_output_loss: 0.6982 - val_y1_output_root_mean_squared_error: 0.4404 - val_y2_output_root_mean_squared_error: 0.8356
# Epoch 487/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3328 - y1_output_loss: 0.1113 - y2_output_loss: 0.2216 - y1_output_root_mean_squared_error: 0.3336 - y2_output_root_mean_squared_error: 0.4707 - val_loss: 0.8351 - val_y1_output_loss: 0.2199 - val_y2_output_loss: 0.6152 - val_y1_output_root_mean_squared_error: 0.4689 - val_y2_output_root_mean_squared_error: 0.7844
# Epoch 488/500
# 62/62 [==============================] - 0s 6ms/step - loss: 0.3765 - y1_output_loss: 0.1185 - y2_output_loss: 0.2580 - y1_output_root_mean_squared_error: 0.3442 - y2_output_root_mean_squared_error: 0.5079 - val_loss: 1.1187 - val_y1_output_loss: 0.4358 - val_y2_output_loss: 0.6829 - val_y1_output_root_mean_squared_error: 0.6602 - val_y2_output_root_mean_squared_error: 0.8264
# Epoch 489/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.2980 - y1_output_loss: 0.1063 - y2_output_loss: 0.1917 - y1_output_root_mean_squared_error: 0.3260 - y2_output_root_mean_squared_error: 0.4378 - val_loss: 0.9847 - val_y1_output_loss: 0.4309 - val_y2_output_loss: 0.5538 - val_y1_output_root_mean_squared_error: 0.6564 - val_y2_output_root_mean_squared_error: 0.7442
# Epoch 490/500
# 62/62 [==============================] - 0s 6ms/step - loss: 0.3205 - y1_output_loss: 0.1151 - y2_output_loss: 0.2054 - y1_output_root_mean_squared_error: 0.3392 - y2_output_root_mean_squared_error: 0.4532 - val_loss: 0.9252 - val_y1_output_loss: 0.2594 - val_y2_output_loss: 0.6658 - val_y1_output_root_mean_squared_error: 0.5093 - val_y2_output_root_mean_squared_error: 0.8160
# Epoch 491/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.3571 - y1_output_loss: 0.1157 - y2_output_loss: 0.2413 - y1_output_root_mean_squared_error: 0.3402 - y2_output_root_mean_squared_error: 0.4913 - val_loss: 1.1797 - val_y1_output_loss: 0.2681 - val_y2_output_loss: 0.9116 - val_y1_output_root_mean_squared_error: 0.5177 - val_y2_output_root_mean_squared_error: 0.9548
# Epoch 492/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4201 - y1_output_loss: 0.1325 - y2_output_loss: 0.2876 - y1_output_root_mean_squared_error: 0.3640 - y2_output_root_mean_squared_error: 0.5363 - val_loss: 1.0981 - val_y1_output_loss: 0.2713 - val_y2_output_loss: 0.8269 - val_y1_output_root_mean_squared_error: 0.5208 - val_y2_output_root_mean_squared_error: 0.9093
# Epoch 493/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4090 - y1_output_loss: 0.1365 - y2_output_loss: 0.2725 - y1_output_root_mean_squared_error: 0.3695 - y2_output_root_mean_squared_error: 0.5220 - val_loss: 1.8543 - val_y1_output_loss: 0.2277 - val_y2_output_loss: 1.6266 - val_y1_output_root_mean_squared_error: 0.4772 - val_y2_output_root_mean_squared_error: 1.2754
# Epoch 494/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.3617 - y1_output_loss: 0.1356 - y2_output_loss: 0.2261 - y1_output_root_mean_squared_error: 0.3683 - y2_output_root_mean_squared_error: 0.4755 - val_loss: 0.8174 - val_y1_output_loss: 0.1817 - val_y2_output_loss: 0.6357 - val_y1_output_root_mean_squared_error: 0.4263 - val_y2_output_root_mean_squared_error: 0.7973
# Epoch 495/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3172 - y1_output_loss: 0.1151 - y2_output_loss: 0.2021 - y1_output_root_mean_squared_error: 0.3393 - y2_output_root_mean_squared_error: 0.4495 - val_loss: 1.2455 - val_y1_output_loss: 0.4172 - val_y2_output_loss: 0.8284 - val_y1_output_root_mean_squared_error: 0.6459 - val_y2_output_root_mean_squared_error: 0.9102
# Epoch 496/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.3665 - y1_output_loss: 0.1276 - y2_output_loss: 0.2388 - y1_output_root_mean_squared_error: 0.3573 - y2_output_root_mean_squared_error: 0.4887 - val_loss: 0.7771 - val_y1_output_loss: 0.1973 - val_y2_output_loss: 0.5798 - val_y1_output_root_mean_squared_error: 0.4442 - val_y2_output_root_mean_squared_error: 0.7614
# Epoch 497/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3425 - y1_output_loss: 0.1198 - y2_output_loss: 0.2228 - y1_output_root_mean_squared_error: 0.3461 - y2_output_root_mean_squared_error: 0.4720 - val_loss: 2.0923 - val_y1_output_loss: 0.2270 - val_y2_output_loss: 1.8652 - val_y1_output_root_mean_squared_error: 0.4765 - val_y2_output_root_mean_squared_error: 1.3657
# Epoch 498/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5168 - y1_output_loss: 0.1425 - y2_output_loss: 0.3743 - y1_output_root_mean_squared_error: 0.3775 - y2_output_root_mean_squared_error: 0.6118 - val_loss: 0.6830 - val_y1_output_loss: 0.1683 - val_y2_output_loss: 0.5148 - val_y1_output_root_mean_squared_error: 0.4102 - val_y2_output_root_mean_squared_error: 0.7175
# Epoch 499/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3716 - y1_output_loss: 0.1431 - y2_output_loss: 0.2285 - y1_output_root_mean_squared_error: 0.3783 - y2_output_root_mean_squared_error: 0.4781 - val_loss: 0.7599 - val_y1_output_loss: 0.1750 - val_y2_output_loss: 0.5849 - val_y1_output_root_mean_squared_error: 0.4184 - val_y2_output_root_mean_squared_error: 0.7648
# Epoch 500/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3659 - y1_output_loss: 0.1105 - y2_output_loss: 0.2554 - y1_output_root_mean_squared_error: 0.3324 - y2_output_root_mean_squared_error: 0.5054 - val_loss: 1.9598 - val_y1_output_loss: 0.6771 - val_y2_output_loss: 1.2828 - val_y1_output_root_mean_squared_error: 0.8229 - val_y2_output_root_mean_squared_error: 1.1326

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 1.9598 - y1_output_loss: 0.6771 - y2_output_loss: 1.2828 - y1_output_root_mean_squared_error: 0.8229 - y2_output_root_mean_squared_error: 1.1326
# Loss = 1.9598444700241089, Y1_loss = 0.6770857572555542, Y1_mse = 0.8228522539138794, Y2_loss = 1.2827585935592651, Y2_mse = 1.132589340209961

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
# Out:
# 5/5 [==============================] - 0s 1ms/step
